# %%
from pmlb import fetch_data, classification_dataset_names
from sklearn.model_selection import train_test_split
print(len(classification_dataset_names))
aim_classification_name = []
data_shapes = []
# Out:
# 162

# %%
for classification_dataset in classification_dataset_names:
    x, y = fetch_data(classification_dataset, return_X_y=True)
    print(x.shape)
    if x.shape[1] < 30:
        aim_classification_name.append(classification_dataset)
        #data_shapes.append((x.shape,y.shape))
# Out:
# (1600, 1000)
# (1600, 20)
# (1600, 20)
# (1600, 20)
# (1600, 20)
# (1600, 20)
# (1212, 100)
# (1212, 100)
# (48842, 14)
# (8145, 22)
# (3772, 29)
# (3771, 29)
# (3770, 29)
# (3772, 29)
# (50, 4)
# (83, 3)
# (841, 70)
# (50, 6)
# (120, 3)
# (132, 3)
# (100, 6)
# (97, 10)
# (92, 10)
# (797, 4)
# (42, 11)
# (400, 5)
# (60, 3)
# (52, 9)
# (264, 4)
# (7200, 21)
# (106, 7)
# (690, 14)
# (202, 25)
# (180, 32)
# (625, 4)
# (209, 8)
# (699, 10)
# (286, 9)
# (569, 30)
# (699, 9)
# (690, 15)
# (345, 5)
# (399, 32)
# (1728, 6)
# (1728, 21)
# (392, 8)
# (3196, 36)
# (5000, 20)
# (476, 168)
# (6598, 168)
# (303, 13)
# (303, 13)
# (303, 7)
# (108, 7)
# (1473, 9)
# (9822, 85)
# (368, 22)
# (485, 23)
# (72, 3)
# (67557, 42)
# (1473, 9)
# (160, 6)
# (690, 15)
# (1000, 20)
# (690, 15)
# (366, 34)
# (768, 8)
# (3772, 29)
# (3186, 180)
# (327, 7)
# (100968, 29)
# (178, 43)
# (1066, 10)
# (1000, 20)
# (205, 9)
# (163, 9)
# (306, 3)
# (160, 4)
# (303, 13)
# (294, 13)
# (270, 13)
# (155, 19)
# (368, 22)
# (435, 16)
# (294, 13)
# (3163, 25)
# (351, 34)
# (150, 4)
# (500, 5)
# (494020, 41)
# (3196, 36)
# (28056, 6)
# (57, 16)
# (3200, 24)
# (3200, 7)
# (20000, 16)
# (87, 3)
# (148, 18)
# (19020, 10)
# (2000, 216)
# (2000, 76)
# (2000, 64)
# (2000, 6)
# (2000, 240)
# (2000, 47)
# (70000, 784)
# (1324, 10)
# (106, 57)
# (556, 6)
# (601, 6)
# (554, 6)
# (360, 90)
# (8124, 22)
# (128, 6)
# (215, 5)
# (12958, 8)
# (5620, 64)
# (5473, 10)
# (32, 5)
# (1124, 10)
# (10992, 16)
# (333, 7)
# (5404, 5)
# (768, 8)
# (1025010, 10)
# (88, 8)
# (200, 7)
# (205, 9)
# (250, 2)
# (672, 9)
# (7400, 20)
# (462, 9)
# (6435, 36)
# (340, 14)
# (2310, 19)
# (58000, 9)
# (105908, 13)
# (315, 12)
# (1066, 12)
# (208, 60)
# (675, 35)
# (4601, 57)
# (267, 22)
# (349, 44)
# (3188, 60)
# (151, 5)
# (5500, 40)
# (512, 9)
# (958, 9)
# (959, 44)
# (7400, 20)
# (846, 18)
# (435, 16)
# (990, 13)
# (5000, 21)
# (5000, 40)
# (569, 30)
# (1599, 11)
# (4898, 11)
# (178, 13)
# (973, 9)
# (1479, 8)

# %%
aim_classification_name
# Out:
# ['GAMETES_Epistasis_2_Way_20atts_0.1H_EDM_1_1',
#  'GAMETES_Epistasis_2_Way_20atts_0.4H_EDM_1_1',
#  'GAMETES_Epistasis_3_Way_20atts_0.2H_EDM_1_1',
#  'GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM_2_001',
#  'GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM_2_001',
#  'adult',
#  'agaricus_lepiota',
#  'allbp',
#  'allhyper',
#  'allhypo',
#  'allrep',
#  'analcatdata_aids',
#  'analcatdata_asbestos',
#  'analcatdata_bankruptcy',
#  'analcatdata_boxing1',
#  'analcatdata_boxing2',
#  'analcatdata_creditscore',
#  'analcatdata_cyyoung8092',
#  'analcatdata_cyyoung9302',
#  'analcatdata_dmft',
#  'analcatdata_fraud',
#  'analcatdata_germangss',
#  'analcatdata_happiness',
#  'analcatdata_japansolvent',
#  'analcatdata_lawsuit',
#  'ann_thyroid',
#  'appendicitis',
#  'australian',
#  'auto',
#  'balance_scale',
#  'biomed',
#  'breast',
#  'breast_cancer',
#  'breast_w',
#  'buggyCrx',
#  'bupa',
#  'car',
#  'car_evaluation',
#  'cars',
#  'churn',
#  'cleve',
#  'cleveland',
#  'cleveland_nominal',
#  'cloud',
#  'cmc',
#  'colic',
#  'collins',
#  'confidence',
#  'contraceptive',
#  'corral',
#  'credit_a',
#  'credit_g',
#  'crx',
#  'diabetes',
#  'dis',
#  'ecoli',
#  'fars',
#  'flare',
#  'german',
#  'glass',
#  'glass2',
#  'haberman',
#  'hayes_roth',
#  'heart_c',
#  'heart_h',
#  'heart_statlog',
#  'hepatitis',
#  'horse_colic',
#  'house_votes_84',
#  'hungarian',
#  'hypothyroid',
#  'iris',
#  'irish',
#  'krkopt',
#  'labor',
#  'led24',
#  'led7',
#  'letter',
#  'lupus',
#  'lymphography',
#  'magic',
#  'mfeat_morphological',
#  'mofn_3_7_10',
#  'monk1',
#  'monk2',
#  'monk3',
#  'mushroom',
#  'mux6',
#  'new_thyroid',
#  'nursery',
#  'page_blocks',
#  'parity5',
#  'parity5+5',
#  'pendigits',
#  'penguins',
#  'phoneme',
#  'pima',
#  'poker',
#  'postoperative_patient_data',
#  'prnn_crabs',
#  'prnn_fglass',
#  'prnn_synth',
#  'profb',
#  'ring',
#  'saheart',
#  'schizo',
#  'segmentation',
#  'shuttle',
#  'sleep',
#  'solar_flare_1',
#  'solar_flare_2',
#  'spect',
#  'tae',
#  'threeOf9',
#  'tic_tac_toe',
#  'twonorm',
#  'vehicle',
#  'vote',
#  'vowel',
#  'waveform_21',
#  'wine_quality_red',
#  'wine_quality_white',
#  'wine_recognition',
#  'xd6',
#  'yeast']
